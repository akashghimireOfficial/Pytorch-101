# %%
import torch 
import torch.nn as nn 


from torchvision import transforms
from torchvision.models import resnet18
from torchvision.datasets import DatasetFolder
from torchsummary import summary

# %% [markdown]
# In this we will learn how we can use pretrained model such as `resnet18()`. We will learn how to fine-tune it:
#
# - Similar to tf, we will freeze all layer(except last few layers)
# - finetune and train on custome model

# %%
## loading the model; torchvision.models.resnet18()
model=resnet18()

# %%
#lets view the model 
model ## we can see model have different layers, and alsolayers have different component
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## Accessing model name and it's modules (top modules as well as all modules (top and sub-modules))
# - model.``named_children()``: To get a dictionary-like view of the top-level layers in the model
# - model.``named_modules ()``: If you want to get all layers and sublayers

# %%
for name,layer in model.named_children(): 
    print(name,':',layer)
# Out:
# conv1 : Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# bn1 : BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# relu : ReLU(inplace=True)
# maxpool : MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# layer1 : Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
# ...

# %%
## accessing sub-layers as well 

names=[]
modules=[]
for name,module in model.named_modules():
    print(name,':',module)
    names.append(name)
# Out:
#  : ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
names
# Out:
# ['',
#  'conv1',
#  'bn1',
#  'relu',
#  'maxpool',
#  'layer1',
#  'layer1.0',
#  'layer1.0.conv1',
#  'layer1.0.bn1',
#  'layer1.0.relu',
#  'layer1.0.conv2',
#  'layer1.0.bn2',
#  'layer1.1',
#  'layer1.1.conv1',
#  'layer1.1.bn1',
#  'layer1.1.relu',
#  'layer1.1.conv2',
#  'layer1.1.bn2',
#  'layer2',
#  'layer2.0',
#  'layer2.0.conv1',
#  'layer2.0.bn1',
#  'layer2.0.relu',
#  'layer2.0.conv2',
#  'layer2.0.bn2',
#  'layer2.0.downsample',
#  'layer2.0.downsample.0',
#  'layer2.0.downsample.1',
#  'layer2.1',
#  'layer2.1.conv1',
#  'layer2.1.bn1',
#  'layer2.1.relu',
#  'layer2.1.conv2',
#  'layer2.1.bn2',
#  'layer3',
#  'layer3.0',
#  'layer3.0.conv1',
#  'layer3.0.bn1',
#  'layer3.0.relu',
#  'layer3.0.conv2',
#  'layer3.0.bn2',
#  'layer3.0.downsample',
#  'layer3.0.downsample.0',
#  'layer3.0.downsample.1',
#  'layer3.1',
#  'layer3.1.conv1',
#  'layer3.1.bn1',
#  'layer3.1.relu',
#  'layer3.1.conv2',
#  'layer3.1.bn2',
#  'layer4',
#  'layer4.0',
#  'layer4.0.conv1',
# ...

# %% [markdown]
# ## Accessing the module
# - ``model.layer4`` refers to the entire layer4 block (which typically consists of multiple sublayers).
# - ``model.layer4[0]`` accesses the first sublayer (index 0) within layer4.

# %%
## Accessing modules 

model.layer4 #modules can be called as methods
# Out:
# Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
# ...

# %%
## Accessing modules with submodules (like sequential model)
model.layer4[0] #sub modules can be accessed as a list
# Out:
# BasicBlock(
#   (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (downsample): Sequential(
#     (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#     (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )

# %% [markdown]
# ## freezing all layers except last layers

# %%
for param in model.parameters(): ##freeezing all the layers
    param.required_grad=False

for param in model.layer4.parameters(): ## layer4 is trainable
    param.required_grad=True

# %% [markdown]
# ## Detaching model and creating another model

# %%
##create a separate model which containing all modules except the last one 
feature_extractor=torch.nn.Sequential(*list(model.children())[:-1])

# %%
feature_extractor
# Out:
# Sequential(
#   (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): ReLU(inplace=True)
#   (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
for child in model.children():
    print(child)
# Out:
# Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
# BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ReLU(inplace=True)
# MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
# Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
# ...
